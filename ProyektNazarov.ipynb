# %% [markdown]
# <a href="https://colab.research.google.com/github/NazarovNikita1/RepForDomashneeZadanie/blob/main/ProyektNazarov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Название проекта: Анализ тенденций кинематографа 20-21 веков

# %% [markdown]
# ## I. Введение
#    - Цели и задачи проекта
#    - Обзор проекта
#
# Цель проекта: произвести анализ данных из датасета Kaggle для выявления трендов
#
# Задачи:
#
# 1. Найти датасет для анализа на платформе Kaggle
# 2. Произвести предварительную обработку данных
# 3. Устроить анализ, какие жанры фильмов предпочитают зрители в разные периоды времени.
# 4. Проанализировать популярные жанры, рейтинги фильмов и кассовые сборы с помощью Pandas.
# 5. Визуализировать данные датасета с помощью Matplotlib
# 6. Вывести несколько правильных и ошибочных результатов, чтобы выявить слабые и сильные стороны выбранного алгоритма
#
# Результаты проекта могут использоваться в качестве теста того или иного датасета.

# %% [markdown]
# ## II. Датасет
# https://www.kaggle.com/datasets/rajugc/imdb-top-250-movies-dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/IMDB Top 250 Movies.csv')
df.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         250 non-null    int64
#  1   name         250 non-null    object
#  2   year         250 non-null    int64
#  3   rating       250 non-null    float64
#  4   genre        250 non-null    object
#  5   certificate  250 non-null    object
#  6   run_time     250 non-null    object
#  7   tagline      250 non-null    object
#  8   budget       250 non-null    object
#  9   box_office   250 non-null    object
#  10  casts        250 non-null    object
#  11  directors    250 non-null    object
#  12  writers      250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB

# %%
#Популярные жанры
popular_genres = df['genre'].value_counts().head(10)

#Рейтинги фильмов
average_ratings = df.groupby('genre')['rating'].mean()

#Кассовые сборы
box_office = df.groupby('genre')['box_office'].sum()

# %%
#Визуализация популярных жанров
popular_genres.plot(kind='bar', title='Top 10 Popular Genres')
plt.xlabel('genre')
plt.ylabel('Number of Movies')
plt.show()

#Визуализация средних рейтингов по жанрам
average_ratings.plot(kind='bar', title='Average Ratings by Genre')
plt.xlabel('genre')
plt.ylabel('rating')
plt.show()

#Визуализация кассовых сборов по жанрам
box_office.plot(kind='bar', title='Box Office by Genre')
plt.xlabel('genre')
plt.ylabel('box_office')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-7ef97d5b7ee3> in <cell line: 14>()
#      12
#      13 #Визуализация кассовых сборов по жанрам
# ---> 14 box_office.plot(kind='bar', title='Box Office by Genre')
#      15 plt.xlabel('genre')
#      16 plt.ylabel('box_office')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
# ...

# %%
print(df.columns)
# Out:
# Index(['rank', 'name', 'year', 'rating', 'genre', 'certificate', 'run_time',
#        'tagline', 'budget', 'box_office', 'casts', 'directors', 'writers'],
#       dtype='object')

# %%
# Показать самые кассовые фильмы
top_grossing_movies = df[['name', 'box_office']].sort_values('box_office', ascending=False).head(10)
print("Самые кассовые фильмы:")
print(top_grossing_movies)
# Out:
# Самые кассовые фильмы:
#                                   name     box_office
# 183                          Gone Girl  Not Available
# 234               My Father and My Son  Not Available
# 124                             Dangal  Not Available
# 195                         Wild Tales  Not Available
# 233                           Jai Bhim  Not Available
# 65   Spider-Man: Into the Spider-Verse  Not Available
# 231                Hachi: A Dog's Tale  Not Available
# 206                        Tokyo Story  Not Available
# 86                        High and Low  Not Available
# 228                           La haine  Not Available

# %%
# Показать самый популярный жанр
most_popular_genre = df['genre'].value_counts().idxmax()
print("Самый популярный жанр:", most_popular_genre)
# Out:
# Самый популярный жанр: Drama

# %%
# Показать самые высокие по рейтингу фильмы
top_rated_movies = df[['name', 'rating']].sort_values('rating', ascending=False).head(10)
print("Самые высокие по рейтингу фильмы:")
print(top_rated_movies)
# Out:
# Самые высокие по рейтингу фильмы:
#                                               name  rating
# 0                         The Shawshank Redemption     9.3
# 1                                    The Godfather     9.2
# 2                                  The Dark Knight     9.0
# 3                            The Godfather Part II     9.0
# 4                                     12 Angry Men     9.0
# 5                                 Schindler's List     9.0
# 6    The Lord of the Rings: The Return of the King     9.0
# 7                                     Pulp Fiction     8.9
# 11                                      Fight Club     8.8
# 233                                       Jai Bhim     8.8

# %%
import matplotlib.pyplot as plt

# Самые кассовые фильмы
plt.figure(figsize=(12, 6))
plt.bar(top_grossing_movies['name'], top_grossing_movies['box_office'], color='blue')
plt.title('Top Grossing Movies')
plt.xlabel('Movie Name')
plt.ylabel('Box Office ($)')
plt.xticks(rotation=90)
plt.show()

# Распределение по жанрам
plt.figure(figsize=(12, 6))
df['genre'].value_counts().plot(kind='bar', color='green')
plt.title('Distribution of Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.xticks(rotation=90)
plt.show()

# Самые высокие по рейтингу фильмы
plt.figure(figsize=(12, 6))
plt.bar(top_rated_movies['name'], top_rated_movies['rating'], color='orange')
plt.title('Top Rated Movies')
plt.xlabel('Movie Name')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Самые провальные фильмы по кассовым сборам
worst_box_office_movies = df.sort_values('box_office')[:10]

# Самые провальные фильмы по рейтингу
worst_rated_movies = df.sort_values('rating')[:10]

plt.figure(figsize=(12, 6))

# Самые провальные фильмы по кассовым сборам
plt.subplot(1, 2, 1)
plt.bar(worst_box_office_movies['name'], worst_box_office_movies['box_office'], color='red')
plt.title('Worst Box Office Movies')
plt.xlabel('Movie Name')
plt.ylabel('Box Office ($)')
plt.xticks(rotation=45, ha='right')

# Самые провальные фильмы по рейтингу
plt.subplot(1, 2, 2)
plt.bar(worst_rated_movies['name'], worst_rated_movies['rating'], color='purple')
plt.title('Worst Rated Movies')
plt.xlabel('Movie Name')
plt.ylabel('Rating')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
# !pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import nltk

nltk.download('punkt')


from nltk.tokenize import word_tokenize
from nltk import FreqDist
def tokenize_text(text):
    tokens = word_tokenize(text)
    return tokens

df = pd.read_csv('/content/IMDB Top 250 Movies.csv')

# Преобразуем столбец 'year' в datetime
df['year'] = pd.to_datetime(df['year'], errors='coerce')

df_selected_genres['genre_tokens'] = df_selected_genres['genre'].apply(tokenize_text)


# Создадим сводную таблицу для подсчета количества фильмов каждого жанра в каждом году
genre_year = df.groupby(['year', 'genre']).size().unstack().fillna(0)

# Нормализуем данные
genre_year_norm = genre_year.div(genre_year.sum(axis=1), axis=0)

# Используем Seaborn для визуализации
plt.figure(figsize=(12, 8))
sns.set_theme(style="darkgrid")  # Устанавливаем тему seaborn
ax = sns.lineplot(data=genre_year_norm[::10], dashes=False)  # Используем каждый 10-й год

# Улучшаем подписи
plt.title('Динамика популярности жанров с 1921 по 2022 год')
plt.xlabel('Год')
plt.ylabel('Доля фильмов по жанрам')

# Перемещаем легенду вне графика
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install spacy
import spacy

nlp = spacy.load("en_core_web_sm")
def extract_named_entities(text):
    doc = nlp(text)
    named_entities = [ent.text for ent in doc.ents]
    return named_entities
df_selected_genres['named_entities'] = df_selected_genres['tagline'].apply(extract_named_entities)
plt.figure(figsize=(12, 8))
sns.set_theme(style="darkgrid")
ax = sns.lineplot(data=genre_year_norm[::10], dashes=False)  #используем каждый 10-й год

plt.title('Динамика популярности выбранных жанров с 1921 по 2022 год')
plt.xlabel('Год')
plt.ylabel('Доля фильмов по жанрам')

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ## III. Выводы
# 1) Разные датасеты = разные данные,
#
# 2) инструменты непросты в пользовании
#
# 3) Узнал больше о датафреймах
#
# 4) Пригодится в будущем: Весь комплекс инструментов и библиотек
#
# 5)
#
# Перспективы:
#       Датасет с фильмами - не очень актуален, но над другими темами можно работать, интересны темы с важными данными (сфера логистики)
